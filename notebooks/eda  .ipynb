# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent.resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print(f"Project root added: {PROJECT_ROOT}")
# Out:
# Project root added: C:\Users\h\Desktop\Week 7\rag-complaint-chatbot

# %%
from src.preprocessor import CFPBDataProcessor

processor = CFPBDataProcessor()

# %%
processor = CFPBDataProcessor()
processor.download_dataset()      # Skip if already done
processor.load_data()       # Chunked + filtered load
processor.perform_eda()
processor.filter_and_clean()
processor.save()
# Out:
# Raw dataset already exists: C:\Users\h\Desktop\Week 7\rag-complaint-chatbot\data\raw\complaints.csv
# Starting memory-safe chunked loading...
# Chunk 1 processed | Filtered so far: 205
# Chunk 2 processed | Filtered so far: 492
# Chunk 3 processed | Filtered so far: 758
# Chunk 4 processed | Filtered so far: 1,117
# Chunk 5 processed | Filtered so far: 1,702
# Chunk 6 processed | Filtered so far: 2,677
# Chunk 7 processed | Filtered so far: 4,028
# Chunk 8 processed | Filtered so far: 6,560
# Chunk 9 processed | Filtered so far: 11,744
# Chunk 10 processed | Filtered so far: 14,736
# Chunk 11 processed | Filtered so far: 16,285
# Chunk 12 processed | Filtered so far: 18,356
# Chunk 13 processed | Filtered so far: 20,409
# Chunk 14 processed | Filtered so far: 21,788
# Chunk 15 processed | Filtered so far: 23,902
# Chunk 16 processed | Filtered so far: 25,326
# Chunk 17 processed | Filtered so far: 26,927
# Chunk 18 processed | Filtered so far: 29,597
# Chunk 19 processed | Filtered so far: 33,405
# Chunk 20 processed | Filtered so far: 46,394
# Chunk 21 processed | Filtered so far: 54,818
# Chunk 22 processed | Filtered so far: 57,682
# Chunk 23 processed | Filtered so far: 60,135
# Chunk 24 processed | Filtered so far: 62,589
# Chunk 25 processed | Filtered so far: 64,925
# Chunk 26 processed | Filtered so far: 67,237
# Chunk 27 processed | Filtered so far: 69,521
# Chunk 28 processed | Filtered so far: 71,140
# Chunk 29 processed | Filtered so far: 72,756
# Chunk 30 processed | Filtered so far: 75,622
# Chunk 31 processed | Filtered so far: 77,977
# Chunk 32 processed | Filtered so far: 80,254
# Chunk 33 processed | Filtered so far: 83,098
# Chunk 34 processed | Filtered so far: 86,628
# Chunk 35 processed | Filtered so far: 90,096
# Chunk 36 processed | Filtered so far: 93,902
# Chunk 37 processed | Filtered so far: 98,071
# Chunk 38 processed | Filtered so far: 102,226
# Chunk 39 processed | Filtered so far: 106,438
# Chunk 40 processed | Filtered so far: 110,836
# Chunk 41 processed | Filtered so far: 115,510
# Chunk 42 processed | Filtered so far: 119,385
# Chunk 43 processed | Filtered so far: 123,824
# Chunk 44 processed | Filtered so far: 128,871
# Chunk 45 processed | Filtered so far: 134,306
# Chunk 46 processed | Filtered so far: 139,401
# Chunk 47 processed | Filtered so far: 144,951
# Chunk 48 processed | Filtered so far: 150,685
# Chunk 49 processed | Filtered so far: 156,189
# Chunk 50 processed | Filtered so far: 162,530
# Chunk 51 processed | Filtered so far: 168,662
# Chunk 52 processed | Filtered so far: 174,699
# Chunk 53 processed | Filtered so far: 180,807
# Chunk 54 processed | Filtered so far: 186,932
# Chunk 55 processed | Filtered so far: 193,270
# Chunk 56 processed | Filtered so far: 199,839
# Chunk 57 processed | Filtered so far: 206,185
# Chunk 58 processed | Filtered so far: 212,882
# Chunk 59 processed | Filtered so far: 219,830
# Chunk 60 processed | Filtered so far: 226,299
# Chunk 61 processed | Filtered so far: 233,183
# Chunk 62 processed | Filtered so far: 239,644
# Chunk 63 processed | Filtered so far: 245,706
# Chunk 64 processed | Filtered so far: 252,188
# Chunk 65 processed | Filtered so far: 258,417
# Chunk 66 processed | Filtered so far: 263,851
# Chunk 67 processed | Filtered so far: 269,275
# Chunk 68 processed | Filtered so far: 273,808
# Chunk 69 processed | Filtered so far: 277,706
# Chunk 70 processed | Filtered so far: 280,197
# Chunk 71 processed | Filtered so far: 282,991
# Chunk 72 processed | Filtered so far: 283,881
# Chunk 73 processed | Filtered so far: 286,414
# Chunk 74 processed | Filtered so far: 292,422
# Chunk 75 processed | Filtered so far: 296,880
# Chunk 76 processed | Filtered so far: 301,944
# Chunk 77 processed | Filtered so far: 307,238
# Chunk 78 processed | Filtered so far: 312,164
# Chunk 79 processed | Filtered so far: 318,929
# Chunk 80 processed | Filtered so far: 323,958
# Chunk 81 processed | Filtered so far: 327,525
# Chunk 82 processed | Filtered so far: 331,096
# Chunk 83 processed | Filtered so far: 334,644
# Chunk 84 processed | Filtered so far: 338,251
# Chunk 85 processed | Filtered so far: 340,394
# Chunk 86 processed | Filtered so far: 342,712
# Chunk 87 processed | Filtered so far: 344,987
# Chunk 88 processed | Filtered so far: 347,079
# Chunk 89 processed | Filtered so far: 349,193
# Chunk 90 processed | Filtered so far: 351,168
# Chunk 91 processed | Filtered so far: 352,790
# Chunk 92 processed | Filtered so far: 354,535
# Chunk 93 processed | Filtered so far: 357,817
# Chunk 94 processed | Filtered so far: 362,730
# Chunk 95 processed | Filtered so far: 367,386
# Chunk 96 processed | Filtered so far: 372,426
# Chunk 97 processed | Filtered so far: 372,873
#
# Loaded & filtered 372,873 relevant complaints
#
# === EDA ===
# Total filtered complaints: 372,873
#
# Product distribution:
# Product
# Checking or savings account                           140319
# Credit card or prepaid card                           108667
# Money transfer, virtual currency, or money service     97188
# Payday loan, title loan, or personal loan              17238
# Consumer Loan                                           9461
# Name: count, dtype: int64
#
# Word count stats:
# count    372873.000000
# mean        206.226528
# std         227.957767
# min           1.000000
# 25%          86.000000
# 50%         135.000000
# 75%         253.000000
# max        6014.000000
# Name: word_count, dtype: float64
# Plot saved: C:\Users\h\Desktop\Week 7\rag-complaint-chatbot\notebooks\narrative_word_count_distribution.png
#
# Mapping categories...
#
# Final distribution:
# product_category
# Savings Accounts    140319
# Credit Cards        108667
# Money Transfers      97188
# Personal Loans       26699
# Name: count, dtype: int64
# Cleaning narratives...
#
# Saved to C:\Users\h\Desktop\Week 7\rag-complaint-chatbot\data\processed\filtered_complaints.csv
# Final records: 372,873

# %%
# %% [markdown]
# # Task 1: EDA on CFPB Complaint Dataset
# This notebook performs exploratory data analysis (EDA) on the filtered complaint dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src.settings import FILTERED_CSV, WORD_COUNT_PLOT, RELEVANT_CFPB_PRODUCTS

sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# %%
# Load the filtered dataset
df = pd.read_csv(FILTERED_CSV)

# Overview
total_complaints = len(df)
print(f"Total complaints in filtered dataset: {total_complaints:,}")

# %%
# Product distribution
product_counts = df['Product'].value_counts()
print("\nProduct distribution:")
display(product_counts)

# Bar plot of product distribution
plt.figure(figsize=(10, 5))
sns.barplot(x=product_counts.index, y=product_counts.values, palette='viridis')
plt.xticks(rotation=45, ha='right')
plt.ylabel("Number of complaints")
plt.title("Distribution of Complaints by Product")
plt.tight_layout()
plt.show()

# %%
# Complaints with vs without narrative
with_narrative = df['Consumer complaint narrative'].notna().sum()
without_narrative = len(df) - with_narrative
print(f"\nComplaints with narrative: {with_narrative:,}")
print(f"Complaints without narrative: {without_narrative:,}")

# %%
# Word count of narratives
df['word_count'] = df['Consumer complaint narrative'].str.split().str.len()
print("\nWord count statistics:")
display(df['word_count'].describe())

# Histogram of word counts
plt.figure(figsize=(12, 6))
sns.histplot(df['word_count'], bins=100, kde=True, color="teal")
plt.title("Narrative Word Count Distribution")
plt.xlabel("Word Count")
plt.ylabel("Frequency")
plt.xlim(0, 1000)  # focus on typical range
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig(WORD_COUNT_PLOT)
plt.show()
print(f"Word count plot saved at {WORD_COUNT_PLOT}")
# Out:
# Total complaints in filtered dataset: 372,873
#
# Product distribution:
# Product
# Checking or savings account                           140319
# Credit card or prepaid card                           108667
# Money transfer, virtual currency, or money service     97188
# Payday loan, title loan, or personal loan              17238
# Consumer Loan                                           9461
# Name: count, dtype: int64
# Complaints with narrative: 372,873
# Complaints without narrative: 0
#
# Word count statistics:
# count    372873.000000
# mean        206.226528
# std         227.957767
# min           1.000000
# 25%          86.000000
# 50%         135.000000
# 75%         253.000000
# max        6014.000000
# Name: word_count, dtype: float64
# Word count plot saved at C:\Users\h\Desktop\Week 7\rag-complaint-chatbot\notebooks\narrative_word_count_distribution.png
